# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 618

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url ="https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'{url}appid={weather_api_key}&q={city}&units=metric'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

#         # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

#     # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | thompson
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | east london
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | saldanha
# Processing Record 7 of Set 1 | dilla
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | georgetown
# Processing Record 11 of Set 1 | nelson bay
# Processing Record 12 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 1 | lompoc
# Processing Record 14 of Set 1 | plettenberg bay
# Processing Record 15 of Set 1 | kavieng
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | chuy
# Processing Record 18 of Set 1 | ahipara
# Processing Record 19 of Set 1 | san patricio
# Processing Record 20 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 1 | broken hill
# Processing Record 22 of Set 1 | botwood
# Processing Record 23 of Set 1 | nishihara
# Processing Record 24 of Set 1 | acapulco
# Processing Record 25 of Set 1 | puerto del rosario
# Processing Record 26 of Set 1 | fort nelson
# Processing Record 27 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | porosozero
# Processing Record 31 of Set 1 | ruatoria
# City not found. Skipping...
# Processing Record 32 of Set 1 | prince rupert
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | de aar
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | kaitangata
# Processing Record 38 of Set 1 | norman wells
# Processing Record 39 of Set 1 | ambodifototra
# City not found. Skipping...
# Processing Record 40 of Set 1 | aljezur
# Processing Record 41 of Set 1 | ahuimanu
# Processing Record 42 of Set 1 | qasigiannguit
# Processing Record 43 of Set 1 | ust-koksa
# Processing Record 44 of Set 1 | sinkat
# City not found. Skipping...
# Processing Record 45 of Set 1 | vaini
# Processing Record 46 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 47 of Set 1 | arys
# Processing Record 48 of Set 1 | tuatapere
# Processing Record 49 of Set 1 | nikolskoye
# Processing Record 50 of Set 1 | vikhorevka
# Processing Record 0 of Set 2 | sioux lookout
# Processing Record 1 of Set 2 | barrow
# Processing Record 2 of Set 2 | jamestown
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | souillac
# Processing Record 5 of Set 2 | yerbogachen
# Processing Record 6 of Set 2 | tromso
# Processing Record 7 of Set 2 | vostok
# Processing Record 8 of Set 2 | qaanaaq
# Processing Record 9 of Set 2 | padrauna
# Processing Record 10 of Set 2 | puerto escondido
# Processing Record 11 of Set 2 | ilulissat
# Processing Record 12 of Set 2 | jalu
# Processing Record 13 of Set 2 | mandalgovi
# Processing Record 14 of Set 2 | bluff
# Processing Record 15 of Set 2 | udachnyy
# Processing Record 16 of Set 2 | korla
# Processing Record 17 of Set 2 | mana
# Processing Record 18 of Set 2 | leningradskiy
# Processing Record 19 of Set 2 | sladkovo
# Processing Record 20 of Set 2 | hohhot
# Processing Record 21 of Set 2 | hovd
# Processing Record 22 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 2 | victoria
# Processing Record 24 of Set 2 | pucara
# Processing Record 25 of Set 2 | tougue
# Processing Record 26 of Set 2 | hobart
# Processing Record 27 of Set 2 | yar-sale
# Processing Record 28 of Set 2 | ponta pora
# Processing Record 29 of Set 2 | karkaralinsk
# City not found. Skipping...
# Processing Record 30 of Set 2 | coquimbo
# Processing Record 31 of Set 2 | hermanus
# Processing Record 32 of Set 2 | sur
# Processing Record 33 of Set 2 | tasiilaq
# Processing Record 34 of Set 2 | port alfred
# Processing Record 35 of Set 2 | san quintin
# Processing Record 36 of Set 2 | pevek
# Processing Record 37 of Set 2 | bengkulu
# Processing Record 38 of Set 2 | cockburn harbour
# City not found. Skipping...
# Processing Record 39 of Set 2 | vardo
# Processing Record 40 of Set 2 | saint george
# Processing Record 41 of Set 2 | cotoca
# Processing Record 42 of Set 2 | zemetchino
# Processing Record 43 of Set 2 | castro
# Processing Record 44 of Set 2 | bloemhof
# Processing Record 45 of Set 2 | saint-philippe
# Processing Record 46 of Set 2 | dikson
# Processing Record 47 of Set 2 | akdepe
# Processing Record 48 of Set 2 | conde
# Processing Record 49 of Set 2 | newport
# Processing Record 0 of Set 3 | hasaki
# Processing Record 1 of Set 3 | katsuura
# Processing Record 2 of Set 3 | bambous virieux
# Processing Record 3 of Set 3 | ixtapa
# Processing Record 4 of Set 3 | umea
# Processing Record 5 of Set 3 | ribeira grande
# Processing Record 6 of Set 3 | bedford
# Processing Record 7 of Set 3 | paamiut
# Processing Record 8 of Set 3 | hambantota
# Processing Record 9 of Set 3 | upernavik
# Processing Record 10 of Set 3 | atar
# Processing Record 11 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 3 | adrar
# Processing Record 13 of Set 3 | dzhebariki-khaya
# Processing Record 14 of Set 3 | biltine
# Processing Record 15 of Set 3 | goderich
# Processing Record 16 of Set 3 | kapaa
# Processing Record 17 of Set 3 | san cristobal
# Processing Record 18 of Set 3 | rio gallegos
# Processing Record 19 of Set 3 | mecca
# Processing Record 20 of Set 3 | beroroha
# Processing Record 21 of Set 3 | nueva gerona
# Processing Record 22 of Set 3 | jasper
# Processing Record 23 of Set 3 | binghamton
# Processing Record 24 of Set 3 | cape town
# Processing Record 25 of Set 3 | mehamn
# Processing Record 26 of Set 3 | saint-francois
# Processing Record 27 of Set 3 | kahului
# Processing Record 28 of Set 3 | varberg
# Processing Record 29 of Set 3 | hami
# Processing Record 30 of Set 3 | saskylakh
# Processing Record 31 of Set 3 | bilibino
# Processing Record 32 of Set 3 | kastamonu
# Processing Record 33 of Set 3 | northam
# Processing Record 34 of Set 3 | tumpat
# Processing Record 35 of Set 3 | port lincoln
# Processing Record 36 of Set 3 | sao filipe
# Processing Record 37 of Set 3 | lagoa
# Processing Record 38 of Set 3 | ola
# Processing Record 39 of Set 3 | ancud
# Processing Record 40 of Set 3 | lebu
# Processing Record 41 of Set 3 | tiksi
# Processing Record 42 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 3 | puksoozero
# Processing Record 44 of Set 3 | grand gaube
# Processing Record 45 of Set 3 | dolores
# Processing Record 46 of Set 3 | ketchikan
# Processing Record 47 of Set 3 | nanma
# Processing Record 48 of Set 3 | laguna
# Processing Record 49 of Set 3 | odweyne
# Processing Record 0 of Set 4 | pundaguitan
# Processing Record 1 of Set 4 | chokurdakh
# Processing Record 2 of Set 4 | porbandar
# Processing Record 3 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 4 | channel-port aux basques
# Processing Record 5 of Set 4 | husavik
# Processing Record 6 of Set 4 | raudeberg
# Processing Record 7 of Set 4 | porto murtinho
# Processing Record 8 of Set 4 | uruacu
# Processing Record 9 of Set 4 | carnarvon
# Processing Record 10 of Set 4 | nanortalik
# Processing Record 11 of Set 4 | tarauaca
# Processing Record 12 of Set 4 | drumnadrochit
# Processing Record 13 of Set 4 | provideniya
# Processing Record 14 of Set 4 | rosetta
# Processing Record 15 of Set 4 | zhuhai
# Processing Record 16 of Set 4 | port blair
# Processing Record 17 of Set 4 | sinjai
# Processing Record 18 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 4 | arraial do cabo
# Processing Record 20 of Set 4 | payo
# Processing Record 21 of Set 4 | bacuit
# City not found. Skipping...
# Processing Record 22 of Set 4 | faanui
# Processing Record 23 of Set 4 | port elizabeth
# Processing Record 24 of Set 4 | atambua
# Processing Record 25 of Set 4 | namatanai
# Processing Record 26 of Set 4 | muravlenko
# Processing Record 27 of Set 4 | shingu
# Processing Record 28 of Set 4 | esperance
# Processing Record 29 of Set 4 | havoysund
# Processing Record 30 of Set 4 | santiago
# Processing Record 31 of Set 4 | kanganpur
# Processing Record 32 of Set 4 | nador
# Processing Record 33 of Set 4 | sinnamary
# Processing Record 34 of Set 4 | cabo san lucas
# Processing Record 35 of Set 4 | batemans bay
# Processing Record 36 of Set 4 | campbell river
# Processing Record 37 of Set 4 | cherskiy
# Processing Record 38 of Set 4 | sechura
# Processing Record 39 of Set 4 | beringovskiy
# Processing Record 40 of Set 4 | aklavik
# Processing Record 41 of Set 4 | hay river
# Processing Record 42 of Set 4 | palas
# Processing Record 43 of Set 4 | rakaia
# Processing Record 44 of Set 4 | malanville
# Processing Record 45 of Set 4 | jinji
# Processing Record 46 of Set 4 | niquelandia
# Processing Record 47 of Set 4 | tocopilla
# Processing Record 48 of Set 4 | itarema
# Processing Record 49 of Set 4 | krasnaya zarya
# Processing Record 0 of Set 5 | kruisfontein
# Processing Record 1 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 5 | bethel
# Processing Record 4 of Set 5 | constitucion
# Processing Record 5 of Set 5 | geraldton
# Processing Record 6 of Set 5 | touros
# Processing Record 7 of Set 5 | flinders
# Processing Record 8 of Set 5 | brigantine
# Processing Record 9 of Set 5 | fairbanks
# Processing Record 10 of Set 5 | champerico
# Processing Record 11 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 5 | hilo
# Processing Record 13 of Set 5 | sitka
# Processing Record 14 of Set 5 | little baguio
# Processing Record 15 of Set 5 | ilhabela
# Processing Record 16 of Set 5 | mancio lima
# Processing Record 17 of Set 5 | chumikan
# Processing Record 18 of Set 5 | severo-kurilsk
# Processing Record 19 of Set 5 | los algarrobos
# Processing Record 20 of Set 5 | ostrovnoy
# Processing Record 21 of Set 5 | margate
# Processing Record 22 of Set 5 | chapais
# Processing Record 23 of Set 5 | guerrero negro
# Processing Record 24 of Set 5 | scarborough
# Processing Record 25 of Set 5 | baker city
# Processing Record 26 of Set 5 | cap malheureux
# Processing Record 27 of Set 5 | alyangula
# Processing Record 28 of Set 5 | gillette
# Processing Record 29 of Set 5 | bandar
# Processing Record 30 of Set 5 | chulym
# Processing Record 31 of Set 5 | sarangani
# Processing Record 32 of Set 5 | muros
# Processing Record 33 of Set 5 | surab
# Processing Record 34 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 5 | mount gambier
# Processing Record 36 of Set 5 | bull savanna
# Processing Record 37 of Set 5 | codrington
# Processing Record 38 of Set 5 | bulanash
# Processing Record 39 of Set 5 | vytegra
# Processing Record 40 of Set 5 | soledade
# Processing Record 41 of Set 5 | ust-kuyga
# Processing Record 42 of Set 5 | eyl
# Processing Record 43 of Set 5 | mokhsogollokh
# Processing Record 44 of Set 5 | ostersund
# Processing Record 45 of Set 5 | karratha
# Processing Record 46 of Set 5 | yulara
# Processing Record 47 of Set 5 | muroto
# Processing Record 48 of Set 5 | san ramon
# Processing Record 49 of Set 5 | isiro
# Processing Record 0 of Set 6 | altamira
# Processing Record 1 of Set 6 | balykshi
# Processing Record 2 of Set 6 | kalmunai
# Processing Record 3 of Set 6 | ushtobe
# Processing Record 4 of Set 6 | wote
# Processing Record 5 of Set 6 | sambava
# Processing Record 6 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 6 | iqaluit
# Processing Record 8 of Set 6 | niigata
# Processing Record 9 of Set 6 | srednekolymsk
# Processing Record 10 of Set 6 | san carlos de bariloche
# Processing Record 11 of Set 6 | mar del plata
# Processing Record 12 of Set 6 | rawson
# Processing Record 13 of Set 6 | izhma
# Processing Record 14 of Set 6 | vydrino
# Processing Record 15 of Set 6 | opelousas
# Processing Record 16 of Set 6 | staryy krym
# Processing Record 17 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 18 of Set 6 | dospat
# Processing Record 19 of Set 6 | manakara
# Processing Record 20 of Set 6 | arman
# Processing Record 21 of Set 6 | butaritari
# Processing Record 22 of Set 6 | green river
# Processing Record 23 of Set 6 | solsvik
# City not found. Skipping...
# Processing Record 24 of Set 6 | mananara
# Processing Record 25 of Set 6 | cayenne
# Processing Record 26 of Set 6 | olinda
# Processing Record 27 of Set 6 | nenjiang
# Processing Record 28 of Set 6 | longyearbyen
# Processing Record 29 of Set 6 | lasa
# Processing Record 30 of Set 6 | new norfolk
# Processing Record 31 of Set 6 | dudinka
# Processing Record 32 of Set 6 | grand-santi
# Processing Record 33 of Set 6 | kidal
# Processing Record 34 of Set 6 | ponta do sol
# Processing Record 35 of Set 6 | esso
# Processing Record 36 of Set 6 | umm lajj
# Processing Record 37 of Set 6 | mahebourg
# Processing Record 38 of Set 6 | olafsvik
# Processing Record 39 of Set 6 | fukue
# Processing Record 40 of Set 6 | unye
# City not found. Skipping...
# Processing Record 41 of Set 6 | linxia
# Processing Record 42 of Set 6 | yatou
# Processing Record 43 of Set 6 | bandipur
# Processing Record 44 of Set 6 | kloulklubed
# Processing Record 45 of Set 6 | padang
# Processing Record 46 of Set 6 | nago
# Processing Record 47 of Set 6 | coahuayana
# Processing Record 48 of Set 6 | maragogi
# Processing Record 49 of Set 6 | luderitz
# Processing Record 0 of Set 7 | bo rai
# Processing Record 1 of Set 7 | takhtamygda
# Processing Record 2 of Set 7 | clyde river
# Processing Record 3 of Set 7 | airai
# Processing Record 4 of Set 7 | krasnoborsk
# Processing Record 5 of Set 7 | coihueco
# Processing Record 6 of Set 7 | grindavik
# Processing Record 7 of Set 7 | edd
# Processing Record 8 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 7 | rocha
# Processing Record 10 of Set 7 | gigmoto
# Processing Record 11 of Set 7 | vityazevo
# Processing Record 12 of Set 7 | puerto el triunfo
# Processing Record 13 of Set 7 | gorkovskoye
# City not found. Skipping...
# Processing Record 14 of Set 7 | tecoanapa
# Processing Record 15 of Set 7 | neiafu
# Processing Record 16 of Set 7 | ayios nikolaos
# Processing Record 17 of Set 7 | sobolevo
# Processing Record 18 of Set 7 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 19 of Set 7 | giyon
# Processing Record 20 of Set 7 | tura
# Processing Record 21 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 7 | vao
# Processing Record 23 of Set 7 | zaranj
# Processing Record 24 of Set 7 | pitimbu
# Processing Record 25 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 7 | nara
# Processing Record 27 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 7 | denpasar
# Processing Record 29 of Set 7 | vila velha
# Processing Record 30 of Set 7 | matsanga
# City not found. Skipping...
# Processing Record 31 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 7 | torbay
# Processing Record 33 of Set 7 | comodoro rivadavia
# Processing Record 34 of Set 7 | lieksa
# Processing Record 35 of Set 7 | limbang
# Processing Record 36 of Set 7 | yagodnoye
# Processing Record 37 of Set 7 | kamaishi
# Processing Record 38 of Set 7 | bubaque
# Processing Record 39 of Set 7 | praia
# Processing Record 40 of Set 7 | richards bay
# Processing Record 41 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 42 of Set 7 | zunyi
# Processing Record 43 of Set 7 | qaqortoq
# Processing Record 44 of Set 7 | mikhaylovka
# Processing Record 45 of Set 7 | lashio
# Processing Record 46 of Set 7 | cidreira
# Processing Record 47 of Set 7 | polican
# Processing Record 48 of Set 7 | narsaq
# Processing Record 49 of Set 7 | coihaique
# Processing Record 0 of Set 8 | buala
# Processing Record 1 of Set 8 | pisco
# Processing Record 2 of Set 8 | inirida
# Processing Record 3 of Set 8 | praia da vitoria
# Processing Record 4 of Set 8 | garca
# Processing Record 5 of Set 8 | ust-kulom
# Processing Record 6 of Set 8 | srem
# Processing Record 7 of Set 8 | corn island
# Processing Record 8 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 9 of Set 8 | morondava
# Processing Record 10 of Set 8 | paragominas
# Processing Record 11 of Set 8 | kodiak
# Processing Record 12 of Set 8 | port pirie
# Processing Record 13 of Set 8 | pacific grove
# Processing Record 14 of Set 8 | miles city
# Processing Record 15 of Set 8 | portland
# Processing Record 16 of Set 8 | bathsheba
# Processing Record 17 of Set 8 | tame
# Processing Record 18 of Set 8 | la ronge
# Processing Record 19 of Set 8 | srikakulam
# Processing Record 20 of Set 8 | san andres
# Processing Record 21 of Set 8 | havre
# Processing Record 22 of Set 8 | san nicolas
# Processing Record 23 of Set 8 | lengshuitan
# Processing Record 24 of Set 8 | rio grande
# Processing Record 25 of Set 8 | fairlie
# Processing Record 26 of Set 8 | cocobeach
# Processing Record 27 of Set 8 | andenes
# Processing Record 28 of Set 8 | kurbnesh
# Processing Record 29 of Set 8 | mackenzie
# Processing Record 30 of Set 8 | gambela
# Processing Record 31 of Set 8 | roald
# Processing Record 32 of Set 8 | ndele
# Processing Record 33 of Set 8 | oussouye
# Processing Record 34 of Set 8 | aviles
# Processing Record 35 of Set 8 | marawi
# Processing Record 36 of Set 8 | itarare
# Processing Record 37 of Set 8 | ginir
# Processing Record 38 of Set 8 | jian
# Processing Record 39 of Set 8 | tambovka
# Processing Record 40 of Set 8 | iquitos
# Processing Record 41 of Set 8 | we
# City not found. Skipping...
# Processing Record 42 of Set 8 | dingle
# Processing Record 43 of Set 8 | katangli
# Processing Record 44 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 45 of Set 8 | hithadhoo
# Processing Record 46 of Set 8 | quatre cocos
# Processing Record 47 of Set 8 | rockport
# Processing Record 48 of Set 8 | ambanja
# Processing Record 49 of Set 8 | hobyo
# Processing Record 0 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 1 of Set 9 | zeya
# Processing Record 2 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 9 | kununurra
# Processing Record 4 of Set 9 | mogadishu
# Processing Record 5 of Set 9 | mahibadhoo
# Processing Record 6 of Set 9 | tuktoyaktuk
# Processing Record 7 of Set 9 | swellendam
# Processing Record 8 of Set 9 | avera
# Processing Record 9 of Set 9 | tilichiki
# Processing Record 10 of Set 9 | kjollefjord
# Processing Record 11 of Set 9 | juegang
# Processing Record 12 of Set 9 | shihezi
# Processing Record 13 of Set 9 | hokitika
# Processing Record 14 of Set 9 | naze
# Processing Record 15 of Set 9 | naivasha
# Processing Record 16 of Set 9 | krasnoselkup
# Processing Record 17 of Set 9 | coronado
# Processing Record 18 of Set 9 | skjervoy
# Processing Record 19 of Set 9 | posse
# Processing Record 20 of Set 9 | kamenka
# Processing Record 21 of Set 9 | beloha
# Processing Record 22 of Set 9 | san isidro
# Processing Record 23 of Set 9 | yumen
# Processing Record 24 of Set 9 | hualmay
# Processing Record 25 of Set 9 | vestmannaeyjar
# Processing Record 26 of Set 9 | boyolangu
# Processing Record 27 of Set 9 | pochutla
# Processing Record 28 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 9 | chingirlau
# Processing Record 30 of Set 9 | san carlos del zulia
# Processing Record 31 of Set 9 | orsk
# Processing Record 32 of Set 9 | icod de los vinos
# Processing Record 33 of Set 9 | usinsk
# Processing Record 34 of Set 9 | nsanje
# Processing Record 35 of Set 9 | bilma
# Processing Record 36 of Set 9 | proletarsk
# Processing Record 37 of Set 9 | havelock
# Processing Record 38 of Set 9 | lewistown
# Processing Record 39 of Set 9 | vila franca do campo
# Processing Record 40 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 9 | maraa
# Processing Record 42 of Set 9 | saint-augustin
# Processing Record 43 of Set 9 | madison
# Processing Record 44 of Set 9 | okhotsk
# Processing Record 45 of Set 9 | anadyr
# Processing Record 46 of Set 9 | pemberton
# Processing Record 47 of Set 9 | nadvoitsy
# Processing Record 48 of Set 9 | bida
# Processing Record 49 of Set 9 | nouadhibou
# Processing Record 0 of Set 10 | hervey bay
# Processing Record 1 of Set 10 | maracaibo
# Processing Record 2 of Set 10 | sabang
# Processing Record 3 of Set 10 | elk city
# Processing Record 4 of Set 10 | alta gracia
# Processing Record 5 of Set 10 | gamba
# Processing Record 6 of Set 10 | vadlapudi
# Processing Record 7 of Set 10 | milford
# Processing Record 8 of Set 10 | innisfail
# Processing Record 9 of Set 10 | atbasar
# Processing Record 10 of Set 10 | novopskov
# Processing Record 11 of Set 10 | aranos
# Processing Record 12 of Set 10 | kindu
# Processing Record 13 of Set 10 | tulsipur
# Processing Record 14 of Set 10 | wajima
# Processing Record 15 of Set 10 | tinoto
# Processing Record 16 of Set 10 | solnechnyy
# Processing Record 17 of Set 10 | kikwit
# Processing Record 18 of Set 10 | tomatlan
# Processing Record 19 of Set 10 | chaozhou
# Processing Record 20 of Set 10 | pfarrkirchen
# Processing Record 21 of Set 10 | los llanos de aridane
# Processing Record 22 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 10 | verkhnyaya toyma
# Processing Record 24 of Set 10 | vanimo
# Processing Record 25 of Set 10 | bontang
# Processing Record 26 of Set 10 | kanniyakumari
# Processing Record 27 of Set 10 | half moon bay
# Processing Record 28 of Set 10 | goundam
# Processing Record 29 of Set 10 | shirpur
# Processing Record 30 of Set 10 | kargopol
# Processing Record 31 of Set 10 | jaramana
# City not found. Skipping...
# Processing Record 32 of Set 10 | ovalle
# Processing Record 33 of Set 10 | lorengau
# Processing Record 34 of Set 10 | santa helena de goias
# Processing Record 35 of Set 10 | corozal
# Processing Record 36 of Set 10 | khomeynishahr
# City not found. Skipping...
# Processing Record 37 of Set 10 | erenhot
# Processing Record 38 of Set 10 | watertown
# Processing Record 39 of Set 10 | miracema do tocantins
# Processing Record 40 of Set 10 | sorland
# Processing Record 41 of Set 10 | ambilobe
# Processing Record 42 of Set 10 | kudahuvadhoo
# Processing Record 43 of Set 10 | labelle
# Processing Record 44 of Set 10 | nakonde
# Processing Record 45 of Set 10 | lavrentiya
# Processing Record 46 of Set 10 | sao joao da barra
# Processing Record 47 of Set 10 | kajaani
# Processing Record 48 of Set 10 | carire
# Processing Record 49 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 0 of Set 11 | talnakh
# Processing Record 1 of Set 11 | gorontalo
# Processing Record 2 of Set 11 | codajas
# Processing Record 3 of Set 11 | talawdi
# City not found. Skipping...
# Processing Record 4 of Set 11 | isangel
# Processing Record 5 of Set 11 | progreso
# Processing Record 6 of Set 11 | tezu
# Processing Record 7 of Set 11 | bakchar
# Processing Record 8 of Set 11 | acajutla
# Processing Record 9 of Set 11 | harper
# Processing Record 10 of Set 11 | clearlake
# Processing Record 11 of Set 11 | pringsewu
# Processing Record 12 of Set 11 | nome
# Processing Record 13 of Set 11 | gornopravdinsk
# Processing Record 14 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 11 | ambovombe
# Processing Record 16 of Set 11 | wilmington
# Processing Record 17 of Set 11 | tecpan
# Processing Record 18 of Set 11 | mapiri
# Processing Record 19 of Set 11 | daru
# Processing Record 20 of Set 11 | petrovac
# Processing Record 21 of Set 11 | baglung
# Processing Record 22 of Set 11 | marzuq
# Processing Record 23 of Set 11 | san policarpo
# Processing Record 24 of Set 11 | orocue
# Processing Record 25 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 26 of Set 11 | bystryy istok
# Processing Record 27 of Set 11 | ihosy
# Processing Record 28 of Set 11 | fortuna
# Processing Record 29 of Set 11 | redlands
# Processing Record 30 of Set 11 | biak
# Processing Record 31 of Set 11 | glendive
# Processing Record 32 of Set 11 | halifax
# Processing Record 33 of Set 11 | grand island
# Processing Record 34 of Set 11 | hadgaon
# Processing Record 35 of Set 11 | mettmann
# Processing Record 36 of Set 11 | horsham
# Processing Record 37 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 11 | shamary
# Processing Record 39 of Set 11 | kachug
# Processing Record 40 of Set 11 | belmonte
# Processing Record 41 of Set 11 | krasnogvardeyskiy
# Processing Record 42 of Set 11 | larsnes
# Processing Record 43 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 44 of Set 11 | umm kaddadah
# Processing Record 45 of Set 11 | tezpur
# Processing Record 46 of Set 11 | sekoma
# Processing Record 47 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 48 of Set 11 | leninsk
# Processing Record 49 of Set 11 | oktyabrskiy
# Processing Record 0 of Set 12 | samarai
# Processing Record 1 of Set 12 | ishigaki
# Processing Record 2 of Set 12 | biscarrosse
# Processing Record 3 of Set 12 | ustyuzhna
# Processing Record 4 of Set 12 | benguela
# Processing Record 5 of Set 12 | tigil
# Processing Record 6 of Set 12 | novopokrovka
# Processing Record 7 of Set 12 | verkhnevilyuysk
# Processing Record 8 of Set 12 | okha
# Processing Record 9 of Set 12 | birjand
# Processing Record 10 of Set 12 | manokwari
# Processing Record 11 of Set 12 | aswan
# Processing Record 12 of Set 12 | velsk
# Processing Record 13 of Set 12 | cortez
# Processing Record 14 of Set 12 | namibe
# Processing Record 15 of Set 12 | gimli
# Processing Record 16 of Set 12 | ugoofaaru
# Processing Record 17 of Set 12 | launceston
# Processing Record 18 of Set 12 | jiayuguan
# Processing Record 19 of Set 12 | buxton
# Processing Record 20 of Set 12 | tecate
# Processing Record 21 of Set 12 | novoselitskoye
# Processing Record 22 of Set 12 | jacksonville
# Processing Record 23 of Set 12 | cuiluan
# Processing Record 24 of Set 12 | yaan
# Processing Record 25 of Set 12 | safaga
# Processing Record 26 of Set 12 | victor harbor
# Processing Record 27 of Set 12 | svetlogorsk
# Processing Record 28 of Set 12 | ust-tsilma
# Processing Record 29 of Set 12 | sao jose da coroa grande
# Processing Record 30 of Set 12 | wattegama
# Processing Record 31 of Set 12 | izumo
# Processing Record 32 of Set 12 | aanekoski
# Processing Record 33 of Set 12 | la rioja
# Processing Record 34 of Set 12 | kankon
# Processing Record 35 of Set 12 | diamantino
# Processing Record 36 of Set 12 | ust-nera
# Processing Record 37 of Set 12 | wageningen
# Processing Record 38 of Set 12 | bonnyville
# Processing Record 39 of Set 12 | swan hill
# Processing Record 40 of Set 12 | batken
# Processing Record 41 of Set 12 | bandar-e lengeh
# Processing Record 42 of Set 12 | yanam
# Processing Record 43 of Set 12 | valparaiso
# Processing Record 44 of Set 12 | palmer
# Processing Record 45 of Set 12 | hinton
# Processing Record 46 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 47 of Set 12 | karwar
# Processing Record 48 of Set 12 | linqiong
# Processing Record 49 of Set 12 | turukhansk
# Processing Record 0 of Set 13 | elizabeth city
# Processing Record 1 of Set 13 | kyra
# Processing Record 2 of Set 13 | port moresby
# Processing Record 3 of Set 13 | wells
# Processing Record 4 of Set 13 | muli
# Processing Record 5 of Set 13 | sao gotardo
# Processing Record 6 of Set 13 | astoria
# Processing Record 7 of Set 13 | marsa matruh
# Processing Record 8 of Set 13 | birao
# Processing Record 9 of Set 13 | kavaratti
# Processing Record 10 of Set 13 | los reyes
# Processing Record 11 of Set 13 | huarmey
# Processing Record 12 of Set 13 | hoi an
# Processing Record 13 of Set 13 | koslan
# Processing Record 14 of Set 13 | lastoursville
# Processing Record 15 of Set 13 | seoul
# Processing Record 16 of Set 13 | komsomolsk
# Processing Record 17 of Set 13 | kabul
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          569
# Lat           569
# Lng           569
# Max Temp      569
# Humidity      569
# Cloudiness    569
# Wind Speed    569
# Country       569
# Date          569
# dtype: int64

# %%
# Display sample data

city_data_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         thompson  55.7435  -97.8558    -15.91        85         100
# 1           albany  42.6001  -73.9662     -1.50        78         100
# 2      east london -33.0153   27.9116     30.52        62          20
# 3        busselton -33.6500  115.3333     18.90        66           1
# 4         khatanga  71.9667  102.5000    -28.11        98         100
# ..             ...      ...       ...       ...       ...         ...
# 564         koslan  63.4564   48.8989    -10.03        96          95
# 565  lastoursville  -0.8143   12.7287     37.56        33          33
# 566          seoul  37.5683  126.9778      7.66        63          75
# 567     komsomolsk  49.0097   33.6455     -0.77        74          64
# 568          kabul  34.5000   69.4167     -4.06        59           0
#
#      Wind Speed Country        Date
# 0          1.54      CA  1676202330
# 1          0.89      US  1676202330
# 2          2.57      ZA  1676202121
# 3          8.31      AU  1676202027
# 4          0.55      RU  1676202332
# ..          ...     ...         ...
# 564        2.07      RU  1676202694
# 565        0.48      GA  1676202695
# 566        2.57      KR  1676202603
# 567        7.98      UA  1676202696
# 568        3.39      AF  1676202458
#
# [569 rows x 9 columns]

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data

city_data_df
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             thompson  55.7435  -97.8558    -15.91        85         100
# 1               albany  42.6001  -73.9662     -1.50        78         100
# 2          east london -33.0153   27.9116     30.52        62          20
# 3            busselton -33.6500  115.3333     18.90        66           1
# 4             khatanga  71.9667  102.5000    -28.11        98         100
# ...                ...      ...       ...       ...       ...         ...
# 564             koslan  63.4564   48.8989    -10.03        96          95
# 565      lastoursville  -0.8143   12.7287     37.56        33          33
# 566              seoul  37.5683  126.9778      7.66        63          75
# 567         komsomolsk  49.0097   33.6455     -0.77        74          64
# 568              kabul  34.5000   69.4167     -4.06        59           0
#
#          Wind Speed Country        Date
# City_ID
# 0              1.54      CA  1676202330
# 1              0.89      US  1676202330
# 2              2.57      ZA  1676202121
# 3              8.31      AU  1676202027
# 4              0.55      RU  1676202332
# ...             ...     ...         ...
# 564            2.07      RU  1676202694
# 565            0.48      GA  1676202695
# 566            2.57      KR  1676202603
# 567            7.98      UA  1676202696
# 568            3.39      AF  1676202458
#
# [569 rows x 9 columns]

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.title("City Max Temperature vs Latitude (2023-02-12)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid()
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'],city_data_df['Humidity'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.title("City Humidity vs Latitude (2023-02-12)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.title("City Cloudiness vs Latitude (2023-02-12)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.title("Wind Speed vs Latitude (2023-02-12)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def computeLinReg (x,y):
    plt.scatter(x,y,marker='o', edgecolor='black')
    plt.grid()

    slope,intercept,rvalue,pvalue,std_err=linregress(x,y)
    regress_values=x*slope+intercept
    line_eq=print(f'The regression equation is y = {round(slope,2)}x + {round(intercept,2)}')
    r=print(f'The r-value is: {rvalue}')
    Rsq=print(f'R squared = {rvalue**2}')
    plt.plot(x,regress_values,"r-")
    
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df=city_data_df.loc[city_data_df['Lat']>=0]

# Display sample data
northern_hemi_df.head(12)
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                  thompson  55.7435  -97.8558    -15.91        85
# 1                    albany  42.6001  -73.9662     -1.50        78
# 4                  khatanga  71.9667  102.5000    -28.11        98
# 6                     dilla   6.4100   38.3100     31.72        10
# 9                georgetown   5.4112  100.3354     29.97        74
# 11                   lompoc  34.6391 -120.4579      7.74        81
# 14              yellowknife  62.4560 -114.3525    -18.58        84
# 17             san patricio  28.0170  -97.5169     10.47        67
# 19                  botwood  49.1499  -55.3482    -12.83        86
# 20                nishihara  26.1842  127.7558     21.81        88
# 21                 acapulco  16.8634  -99.8901     22.90        88
# 22       puerto del rosario  28.5004  -13.8627     18.86        48
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        1.54      CA  1676202330
# 1               100        0.89      US  1676202330
# 4               100        0.55      RU  1676202332
# 6                 0        2.87      ET  1676202333
# 9                20        3.09      MY  1676202136
# 11               20        1.34      US  1676202336
# 14               75        3.09      CA  1676202104
# 17               61        2.19      US  1676202340
# 19               31        3.23      CA  1676202342
# 20               75        3.60      JP  1676202342
# 21               40        2.06      MX  1676202343
# 22               49        5.66      ES  1676202343

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df.loc[city_data_df['Lat']<=0]

# Display sample data
southern_hemi_df.head(12)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2            east london -33.0153   27.9116     30.52        62          20
# 3              busselton -33.6500  115.3333     18.90        66           1
# 5               saldanha -33.0117   17.9442     21.11        74          45
# 7                mataura -46.1927  168.8643     11.72        99          78
# 8                rikitea -23.1203 -134.9692     25.34        73          62
# 10            nelson bay -32.7167  152.1500     23.94        91          30
# 12       plettenberg bay -34.0527   23.3716     25.60        63          48
# 13               kavieng  -2.5744  150.7967     26.96        81          98
# 15                  chuy -33.6971  -53.4616     27.25        47          24
# 16               ahipara -35.1667  173.1667     19.27        93         100
# 18           broken hill -31.9500  141.4333     23.51        23          40
# 24                avarua -21.2078 -159.7750     26.03        89         100
#
#          Wind Speed Country        Date
# City_ID
# 2              2.57      ZA  1676202121
# 3              8.31      AU  1676202027
# 5              5.80      ZA  1676202332
# 7              0.74      NZ  1676202333
# 8              2.21      PF  1676202334
# 10             4.02      AU  1676202335
# 12             4.32      ZA  1676202337
# 13             6.10      PG  1676202337
# 15             3.50      UY  1676202339
# 16             8.75      NZ  1676202339
# 18             5.25      AU  1676202341
# 24             1.54      CK  1676202117

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
computeLinReg(northern_hemi_df['Lat'],northern_hemi_df['Max Temp'])
# Out:
# The regression equation is y = -0.77x + 35.52
# The r-value is: -0.863266937972359
# R squared = 0.7452298061961727

# %%
# Linear regression on Southern Hemisphere
computeLinReg(southern_hemi_df['Lat'],southern_hemi_df['Max Temp'])
# Out:
# The regression equation is y = 0.23x + 29.13
# The r-value is: 0.5195970851001898
# R squared = 0.26998113084461384

# %% [markdown]
# **Discussion about the linear relationship:** In the Northern hemisphere, there is a strong negative correlation between max temperature and degrees of latitude. In other words, the further away from the equator (0 degrees latitude) a city is located, the lower the max temperature is. The R-squared number is 0.745 - i.e. changes in latitude (x) explain 74.5% of the changes in variable y, max temperature.
#
# In the Southern hemisphere there is a weaker relationship between max temperature and latitude. However the figure shows that as latitude approaches 0, temperatures get warmer.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
computeLinReg(northern_hemi_df['Lat'],northern_hemi_df['Humidity'])
# Out:
# The regression equation is y = 0.52x + 53.6
# The r-value is: 0.451611298621235
# R squared = 0.2039527650423583

# %%
# Southern Hemisphere
computeLinReg(southern_hemi_df['Lat'],southern_hemi_df['Humidity'])
# Out:
# The regression equation is y = 0.28x + 76.92
# The r-value is: 0.19485237023675447
# R squared = 0.03796744618688124

# %% [markdown]
# **Discussion about the linear relationship:** There appears to be a weak linear relationship between Latitude and humidity in both northern and southern hemispheres. This means that in the northern hemisphere, humidity increases slightly as you move away from the equator; and in the south humidity increases as you approach the equator. However, the low R-squared scores suggest there may be external factors (not Latitude) that explains this.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
computeLinReg(northern_hemi_df['Lat'],northern_hemi_df['Cloudiness'])
# Out:
# The regression equation is y = 0.68x + 30.1
# The r-value is: 0.3442863346763885
# R squared = 0.11853308024490217

# %%
# Southern Hemisphere
computeLinReg(southern_hemi_df['Lat'],southern_hemi_df['Cloudiness'])
# Out:
# The regression equation is y = 1.29x + 86.22
# The r-value is: 0.4716060780144082
# R squared = 0.22241229282013206

# %% [markdown]
# **Discussion about the linear relationship:** There appears to be a weak linear relationship between Latitude and cloudiness in both northern and southern hemispheres. This means that in the northern hemisphere, cloud cover increases slightly as you move away from the equator; and in the south cloud cover slightly increases as you approach the equator. However, the low R-squared scores suggest there may be external factors (not Latitude) that explains this.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
computeLinReg(northern_hemi_df['Lat'],northern_hemi_df['Wind Speed'])
# Out:
# The regression equation is y = 0.01x + 3.57
# The r-value is: 0.06767854124087412
# R squared = 0.004580384944492699

# %%
# Southern Hemisphere
computeLinReg(southern_hemi_df['Lat'],southern_hemi_df['Wind Speed'])
# Out:
# The regression equation is y = -0.04x + 2.57
# The r-value is: -0.2506337512974957
# R squared = 0.06281727728945494

# %% [markdown]
# **Discussion about the linear relationship:** There appears to be little to no linear relationship between Latitude and wind speed in either hemisphere.
