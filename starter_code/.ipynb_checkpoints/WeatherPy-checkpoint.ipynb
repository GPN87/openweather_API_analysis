# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 624

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url ="https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'{url}appid={weather_api_key}&q={city}&units=metric'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

#         # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

#     # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | qaanaaq
# Processing Record 2 of Set 1 | binzhou
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | oume
# Processing Record 5 of Set 1 | klaksvik
# Processing Record 6 of Set 1 | bedford
# Processing Record 7 of Set 1 | thunder bay
# Processing Record 8 of Set 1 | mulhouse
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | talnakh
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | butaritari
# Processing Record 14 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 1 | zhoucheng
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | ponta do sol
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | cidreira
# Processing Record 20 of Set 1 | houston
# Processing Record 21 of Set 1 | nikolskoye
# Processing Record 22 of Set 1 | dien bien
# City not found. Skipping...
# Processing Record 23 of Set 1 | le port
# Processing Record 24 of Set 1 | atuona
# Processing Record 25 of Set 1 | aykhal
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 1 | haines junction
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | casablanca
# Processing Record 31 of Set 1 | port elizabeth
# Processing Record 32 of Set 1 | fallbrook
# Processing Record 33 of Set 1 | ahuimanu
# Processing Record 34 of Set 1 | uppsala
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | artyom
# Processing Record 37 of Set 1 | joshimath
# Processing Record 38 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | shubarshi
# Processing Record 41 of Set 1 | bereda
# Processing Record 42 of Set 1 | walvis bay
# Processing Record 43 of Set 1 | soanierana ivongo
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | piopio
# Processing Record 46 of Set 1 | redmond
# Processing Record 47 of Set 1 | saldanha
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | saint-philippe
# Processing Record 50 of Set 1 | cherskiy
# Processing Record 0 of Set 2 | korla
# Processing Record 1 of Set 2 | ornskoldsvik
# Processing Record 2 of Set 2 | dano
# Processing Record 3 of Set 2 | hudson bay
# Processing Record 4 of Set 2 | padang
# Processing Record 5 of Set 2 | berdigestyakh
# Processing Record 6 of Set 2 | clyde river
# Processing Record 7 of Set 2 | floro
# Processing Record 8 of Set 2 | porto novo
# Processing Record 9 of Set 2 | broken hill
# Processing Record 10 of Set 2 | hasaki
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | kermanshah
# Processing Record 13 of Set 2 | manta
# Processing Record 14 of Set 2 | tasiilaq
# Processing Record 15 of Set 2 | anadyr
# Processing Record 16 of Set 2 | dikson
# Processing Record 17 of Set 2 | busselton
# Processing Record 18 of Set 2 | kodiak
# Processing Record 19 of Set 2 | mar del plata
# Processing Record 20 of Set 2 | half moon bay
# Processing Record 21 of Set 2 | avarua
# Processing Record 22 of Set 2 | vodnyy
# Processing Record 23 of Set 2 | port alfred
# Processing Record 24 of Set 2 | grand gaube
# Processing Record 25 of Set 2 | guerrero negro
# Processing Record 26 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 27 of Set 2 | aklavik
# Processing Record 28 of Set 2 | shenjiamen
# Processing Record 29 of Set 2 | kamenka
# Processing Record 30 of Set 2 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 31 of Set 2 | obo
# Processing Record 32 of Set 2 | tuy hoa
# Processing Record 33 of Set 2 | kaitangata
# Processing Record 34 of Set 2 | yumen
# Processing Record 35 of Set 2 | lakes entrance
# Processing Record 36 of Set 2 | tigil
# Processing Record 37 of Set 2 | mwense
# Processing Record 38 of Set 2 | lamar
# Processing Record 39 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 2 | at-bashi
# Processing Record 41 of Set 2 | avera
# Processing Record 42 of Set 2 | sirfa
# City not found. Skipping...
# Processing Record 43 of Set 2 | norman wells
# Processing Record 44 of Set 2 | ambilobe
# Processing Record 45 of Set 2 | juneau
# Processing Record 46 of Set 2 | fort nelson
# Processing Record 47 of Set 2 | sadovoye
# Processing Record 48 of Set 2 | tuktoyaktuk
# Processing Record 49 of Set 2 | verkhoyansk
# Processing Record 0 of Set 3 | nagornskiy
# Processing Record 1 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 3 | ilulissat
# Processing Record 3 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 3 | bac lieu
# Processing Record 5 of Set 3 | pangnirtung
# Processing Record 6 of Set 3 | annonay
# Processing Record 7 of Set 3 | bilibino
# Processing Record 8 of Set 3 | soavinandriana
# Processing Record 9 of Set 3 | lagoa
# Processing Record 10 of Set 3 | khatanga
# Processing Record 11 of Set 3 | tabou
# Processing Record 12 of Set 3 | bathsheba
# Processing Record 13 of Set 3 | loviisa
# Processing Record 14 of Set 3 | fernandopolis
# Processing Record 15 of Set 3 | arraial do cabo
# Processing Record 16 of Set 3 | clearwater
# Processing Record 17 of Set 3 | valera
# Processing Record 18 of Set 3 | tiksi
# Processing Record 19 of Set 3 | chester
# Processing Record 20 of Set 3 | bluff
# Processing Record 21 of Set 3 | nogales
# Processing Record 22 of Set 3 | ancud
# Processing Record 23 of Set 3 | souris
# Processing Record 24 of Set 3 | gorom-gorom
# Processing Record 25 of Set 3 | port keats
# Processing Record 26 of Set 3 | zemio
# Processing Record 27 of Set 3 | hofn
# Processing Record 28 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 3 | palu
# Processing Record 30 of Set 3 | along
# Processing Record 31 of Set 3 | kasongo-lunda
# Processing Record 32 of Set 3 | chuy
# Processing Record 33 of Set 3 | qiongshan
# Processing Record 34 of Set 3 | nantai
# Processing Record 35 of Set 3 | kangasala
# Processing Record 36 of Set 3 | geraldton
# Processing Record 37 of Set 3 | sarka ghat
# Processing Record 38 of Set 3 | roma
# Processing Record 39 of Set 3 | yellowknife
# Processing Record 40 of Set 3 | mecca
# Processing Record 41 of Set 3 | quedlinburg
# Processing Record 42 of Set 3 | lebu
# Processing Record 43 of Set 3 | kuytun
# Processing Record 44 of Set 3 | moose factory
# Processing Record 45 of Set 3 | pokhara
# Processing Record 46 of Set 3 | opuwo
# Processing Record 47 of Set 3 | hobart
# Processing Record 48 of Set 3 | beidao
# Processing Record 49 of Set 3 | jiamusi
# Processing Record 0 of Set 4 | sistranda
# Processing Record 1 of Set 4 | hobyo
# Processing Record 2 of Set 4 | wa
# City not found. Skipping...
# Processing Record 3 of Set 4 | ribeira grande
# Processing Record 4 of Set 4 | kundiawa
# Processing Record 5 of Set 4 | frontera
# Processing Record 6 of Set 4 | roebourne
# Processing Record 7 of Set 4 | apostolove
# Processing Record 8 of Set 4 | galle
# Processing Record 9 of Set 4 | kralendijk
# Processing Record 10 of Set 4 | banda aceh
# Processing Record 11 of Set 4 | rocha
# Processing Record 12 of Set 4 | lander
# Processing Record 13 of Set 4 | samdrup jongkhar
# Processing Record 14 of Set 4 | luderitz
# Processing Record 15 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 4 | provideniya
# Processing Record 17 of Set 4 | severo-kurilsk
# Processing Record 18 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 4 | santa isabel do rio negro
# Processing Record 20 of Set 4 | hithadhoo
# Processing Record 21 of Set 4 | kwekwe
# Processing Record 22 of Set 4 | necochea
# Processing Record 23 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 4 | saskylakh
# Processing Record 25 of Set 4 | nelson bay
# Processing Record 26 of Set 4 | amuntai
# Processing Record 27 of Set 4 | naze
# Processing Record 28 of Set 4 | dunedin
# Processing Record 29 of Set 4 | yarkovo
# Processing Record 30 of Set 4 | khartoum
# Processing Record 31 of Set 4 | chiredzi
# Processing Record 32 of Set 4 | ulagan
# Processing Record 33 of Set 4 | knysna
# Processing Record 34 of Set 4 | rawson
# Processing Record 35 of Set 4 | oktyabrskiy
# Processing Record 36 of Set 4 | spirit river
# Processing Record 37 of Set 4 | parabel
# Processing Record 38 of Set 4 | katsuura
# Processing Record 39 of Set 4 | dingle
# Processing Record 40 of Set 4 | takoradi
# Processing Record 41 of Set 4 | bairiki
# Processing Record 42 of Set 4 | lavrentiya
# Processing Record 43 of Set 4 | chake chake
# Processing Record 44 of Set 4 | muzhi
# Processing Record 45 of Set 4 | salinas
# Processing Record 46 of Set 4 | rancho palos verdes
# Processing Record 47 of Set 4 | ostrovnoy
# Processing Record 48 of Set 4 | mahebourg
# Processing Record 49 of Set 4 | hirara
# Processing Record 0 of Set 5 | yerkoy
# Processing Record 1 of Set 5 | turka
# Processing Record 2 of Set 5 | gushikawa
# Processing Record 3 of Set 5 | palmer
# Processing Record 4 of Set 5 | waddan
# Processing Record 5 of Set 5 | vienna
# Processing Record 6 of Set 5 | tortosa
# Processing Record 7 of Set 5 | ambunti
# Processing Record 8 of Set 5 | bredasdorp
# Processing Record 9 of Set 5 | kosgi
# City not found. Skipping...
# Processing Record 10 of Set 5 | shieli
# Processing Record 11 of Set 5 | roros
# Processing Record 12 of Set 5 | udachnyy
# Processing Record 13 of Set 5 | teknaf
# Processing Record 14 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 5 | mount isa
# Processing Record 16 of Set 5 | fortuna
# Processing Record 17 of Set 5 | shingu
# Processing Record 18 of Set 5 | kango
# Processing Record 19 of Set 5 | constitucion
# Processing Record 20 of Set 5 | puerto ayora
# Processing Record 21 of Set 5 | georgetown
# Processing Record 22 of Set 5 | whitehorse
# Processing Record 23 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 5 | yarada
# Processing Record 25 of Set 5 | la ronge
# Processing Record 26 of Set 5 | bengkulu
# Processing Record 27 of Set 5 | durango
# Processing Record 28 of Set 5 | farah
# Processing Record 29 of Set 5 | the valley
# Processing Record 30 of Set 5 | mhasla
# Processing Record 31 of Set 5 | baiyin
# Processing Record 32 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 5 | oranjemund
# Processing Record 34 of Set 5 | sorland
# Processing Record 35 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 5 | victoria
# Processing Record 37 of Set 5 | barra da estiva
# Processing Record 38 of Set 5 | afanasyevo
# City not found. Skipping...
# Processing Record 39 of Set 5 | guanare
# Processing Record 40 of Set 5 | marawi
# Processing Record 41 of Set 5 | tupik
# Processing Record 42 of Set 5 | saint-louis
# Processing Record 43 of Set 5 | poso
# Processing Record 44 of Set 5 | dibaya
# City not found. Skipping...
# Processing Record 45 of Set 5 | kirakira
# Processing Record 46 of Set 5 | wanlaweyn
# Processing Record 47 of Set 5 | narsaq
# Processing Record 48 of Set 5 | saint-pierre
# Processing Record 49 of Set 5 | barrow
# Processing Record 0 of Set 6 | biankouma
# Processing Record 1 of Set 6 | plettenberg bay
# Processing Record 2 of Set 6 | chokurdakh
# Processing Record 3 of Set 6 | norden
# Processing Record 4 of Set 6 | leningradskiy
# Processing Record 5 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 6 | cabo san lucas
# Processing Record 7 of Set 6 | kahului
# Processing Record 8 of Set 6 | husavik
# Processing Record 9 of Set 6 | boueni
# Processing Record 10 of Set 6 | mount gambier
# Processing Record 11 of Set 6 | east london
# Processing Record 12 of Set 6 | padilla
# Processing Record 13 of Set 6 | mandurah
# Processing Record 14 of Set 6 | mulchen
# Processing Record 15 of Set 6 | krasnoarmeysk
# Processing Record 16 of Set 6 | iqaluit
# Processing Record 17 of Set 6 | carnarvon
# Processing Record 18 of Set 6 | slave lake
# Processing Record 19 of Set 6 | nador
# Processing Record 20 of Set 6 | tual
# Processing Record 21 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 22 of Set 6 | saint george
# Processing Record 23 of Set 6 | rantauprapat
# Processing Record 24 of Set 6 | margate
# Processing Record 25 of Set 6 | ngama
# Processing Record 26 of Set 6 | shaunavon
# Processing Record 27 of Set 6 | alofi
# Processing Record 28 of Set 6 | sitka
# Processing Record 29 of Set 6 | komsomolskiy
# Processing Record 30 of Set 6 | riyadh
# Processing Record 31 of Set 6 | igrim
# Processing Record 32 of Set 6 | rio grande city
# Processing Record 33 of Set 6 | bonavista
# Processing Record 34 of Set 6 | asosa
# Processing Record 35 of Set 6 | cayenne
# Processing Record 36 of Set 6 | soubre
# Processing Record 37 of Set 6 | piracanjuba
# Processing Record 38 of Set 6 | mayor pablo lagerenza
# Processing Record 39 of Set 6 | vao
# Processing Record 40 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 6 | matara
# Processing Record 42 of Set 6 | puerto leguizamo
# Processing Record 43 of Set 6 | san quintin
# Processing Record 44 of Set 6 | sobolevo
# Processing Record 45 of Set 6 | tsentralnyy
# City not found. Skipping...
# Processing Record 46 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 6 | beringovskiy
# Processing Record 48 of Set 6 | coahuayana
# Processing Record 49 of Set 6 | upernavik
# Processing Record 0 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 1 of Set 7 | kavaratti
# Processing Record 2 of Set 7 | sabang
# Processing Record 3 of Set 7 | sarkand
# Processing Record 4 of Set 7 | luocheng
# Processing Record 5 of Set 7 | camopi
# Processing Record 6 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 7 | meulaboh
# Processing Record 8 of Set 7 | tateyama
# Processing Record 9 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 7 | pangkalanbuun
# Processing Record 11 of Set 7 | vostok
# Processing Record 12 of Set 7 | samarai
# Processing Record 13 of Set 7 | nzega
# Processing Record 14 of Set 7 | chumikan
# Processing Record 15 of Set 7 | esperance
# Processing Record 16 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 17 of Set 7 | goderich
# Processing Record 18 of Set 7 | bethel
# Processing Record 19 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 7 | valkeakoski
# Processing Record 21 of Set 7 | dakar
# Processing Record 22 of Set 7 | bolshiye uki
# City not found. Skipping...
# Processing Record 23 of Set 7 | puerto carreno
# Processing Record 24 of Set 7 | saint anthony
# Processing Record 25 of Set 7 | sukhobezvodnoye
# Processing Record 26 of Set 7 | ixtapa
# Processing Record 27 of Set 7 | zhigansk
# Processing Record 28 of Set 7 | los llanos de aridane
# Processing Record 29 of Set 7 | doha
# Processing Record 30 of Set 7 | mocuba
# Processing Record 31 of Set 7 | kargasok
# Processing Record 32 of Set 7 | lorengau
# Processing Record 33 of Set 7 | dukat
# Processing Record 34 of Set 7 | hualmay
# Processing Record 35 of Set 7 | karpathos
# Processing Record 36 of Set 7 | qui nhon
# Processing Record 37 of Set 7 | pisco
# Processing Record 38 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 7 | panama city
# Processing Record 40 of Set 7 | charters towers
# Processing Record 41 of Set 7 | kaspiysk
# Processing Record 42 of Set 7 | funadhoo
# Processing Record 43 of Set 7 | bjornevatn
# Processing Record 44 of Set 7 | maarianhamina
# Processing Record 45 of Set 7 | adre
# Processing Record 46 of Set 7 | langfang
# Processing Record 47 of Set 7 | henties bay
# Processing Record 48 of Set 7 | soyo
# Processing Record 49 of Set 7 | wang saphung
# Processing Record 0 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 1 of Set 8 | ustyuzhna
# Processing Record 2 of Set 8 | diego de almagro
# Processing Record 3 of Set 8 | novyy urgal
# Processing Record 4 of Set 8 | thompson
# Processing Record 5 of Set 8 | alenquer
# Processing Record 6 of Set 8 | ndola
# Processing Record 7 of Set 8 | havre-saint-pierre
# Processing Record 8 of Set 8 | pevek
# Processing Record 9 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 10 of Set 8 | yantal
# Processing Record 11 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 8 | rebrikha
# Processing Record 13 of Set 8 | hokitika
# Processing Record 14 of Set 8 | republic
# Processing Record 15 of Set 8 | puerto escondido
# Processing Record 16 of Set 8 | biak
# Processing Record 17 of Set 8 | urusha
# Processing Record 18 of Set 8 | ponte nova
# Processing Record 19 of Set 8 | namibe
# Processing Record 20 of Set 8 | tsienyane
# City not found. Skipping...
# Processing Record 21 of Set 8 | ondjiva
# Processing Record 22 of Set 8 | tautira
# Processing Record 23 of Set 8 | srednekolymsk
# Processing Record 24 of Set 8 | morant bay
# Processing Record 25 of Set 8 | chicama
# Processing Record 26 of Set 8 | diamantino
# Processing Record 27 of Set 8 | namatanai
# Processing Record 28 of Set 8 | souillac
# Processing Record 29 of Set 8 | makali
# Processing Record 30 of Set 8 | vila velha
# Processing Record 31 of Set 8 | mehamn
# Processing Record 32 of Set 8 | lalomanu
# City not found. Skipping...
# Processing Record 33 of Set 8 | deputatskiy
# Processing Record 34 of Set 8 | bambanglipuro
# Processing Record 35 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 8 | kavieng
# Processing Record 37 of Set 8 | ugoofaaru
# Processing Record 38 of Set 8 | bardiyah
# Processing Record 39 of Set 8 | zanjan
# Processing Record 40 of Set 8 | boissevain
# Processing Record 41 of Set 8 | itarema
# Processing Record 42 of Set 8 | micheweni
# Processing Record 43 of Set 8 | castro
# Processing Record 44 of Set 8 | asau
# Processing Record 45 of Set 8 | kuching
# Processing Record 46 of Set 8 | inuvik
# Processing Record 47 of Set 8 | millinocket
# Processing Record 48 of Set 8 | atambua
# Processing Record 49 of Set 8 | port hedland
# Processing Record 0 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 1 of Set 9 | huarmey
# Processing Record 2 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 3 of Set 9 | catuday
# Processing Record 4 of Set 9 | shymkent
# Processing Record 5 of Set 9 | cedral
# Processing Record 6 of Set 9 | nalut
# Processing Record 7 of Set 9 | jiuquan
# Processing Record 8 of Set 9 | macara
# Processing Record 9 of Set 9 | marquette
# Processing Record 10 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 9 | chalmette
# Processing Record 12 of Set 9 | tolmachevo
# Processing Record 13 of Set 9 | lompoc
# Processing Record 14 of Set 9 | jaisalmer
# Processing Record 15 of Set 9 | torbay
# Processing Record 16 of Set 9 | dalvik
# Processing Record 17 of Set 9 | aksarka
# Processing Record 18 of Set 9 | sola
# Processing Record 19 of Set 9 | adrar
# Processing Record 20 of Set 9 | lakatoro
# Processing Record 21 of Set 9 | harboore
# Processing Record 22 of Set 9 | port hueneme
# Processing Record 23 of Set 9 | parbhani
# Processing Record 24 of Set 9 | faanui
# Processing Record 25 of Set 9 | dubbo
# Processing Record 26 of Set 9 | haapiti
# Processing Record 27 of Set 9 | emba
# Processing Record 28 of Set 9 | colesberg
# Processing Record 29 of Set 9 | nisia floresta
# Processing Record 30 of Set 9 | senanga
# Processing Record 31 of Set 9 | ust-maya
# Processing Record 32 of Set 9 | desaguadero
# Processing Record 33 of Set 9 | ust-kuyga
# Processing Record 34 of Set 9 | auki
# Processing Record 35 of Set 9 | poum
# Processing Record 36 of Set 9 | napierville
# Processing Record 37 of Set 9 | chernyshevskiy
# Processing Record 38 of Set 9 | grand-santi
# Processing Record 39 of Set 9 | bambous virieux
# Processing Record 40 of Set 9 | lexington
# Processing Record 41 of Set 9 | faya
# Processing Record 42 of Set 9 | vangaindrano
# Processing Record 43 of Set 9 | hovd
# Processing Record 44 of Set 9 | yabelo
# Processing Record 45 of Set 9 | makakilo city
# Processing Record 46 of Set 9 | laguna
# Processing Record 47 of Set 9 | nyurba
# Processing Record 48 of Set 9 | svobodnyy
# Processing Record 49 of Set 9 | fort dodge
# Processing Record 0 of Set 10 | comodoro rivadavia
# Processing Record 1 of Set 10 | burgos
# Processing Record 2 of Set 10 | kropotkin
# Processing Record 3 of Set 10 | bandarbeyla
# Processing Record 4 of Set 10 | bograd
# Processing Record 5 of Set 10 | broome
# Processing Record 6 of Set 10 | shimoda
# Processing Record 7 of Set 10 | synya
# Processing Record 8 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 9 of Set 10 | tlahualilo
# City not found. Skipping...
# Processing Record 10 of Set 10 | collie
# Processing Record 11 of Set 10 | shache
# Processing Record 12 of Set 10 | lethem
# Processing Record 13 of Set 10 | kaifeng
# Processing Record 14 of Set 10 | glencoe
# Processing Record 15 of Set 10 | gladstone
# Processing Record 16 of Set 10 | colquechaca
# Processing Record 17 of Set 10 | mason city
# Processing Record 18 of Set 10 | bosaso
# Processing Record 19 of Set 10 | mongomo
# Processing Record 20 of Set 10 | ipixuna
# Processing Record 21 of Set 10 | sangar
# Processing Record 22 of Set 10 | tougan
# Processing Record 23 of Set 10 | west wendover
# Processing Record 24 of Set 10 | vesoul
# Processing Record 25 of Set 10 | richards bay
# Processing Record 26 of Set 10 | svetlogorsk
# Processing Record 27 of Set 10 | key largo
# Processing Record 28 of Set 10 | coquimbo
# Processing Record 29 of Set 10 | pacific grove
# Processing Record 30 of Set 10 | andenes
# Processing Record 31 of Set 10 | saquisili
# Processing Record 32 of Set 10 | sri aman
# Processing Record 33 of Set 10 | vila do maio
# Processing Record 34 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 35 of Set 10 | arrah
# Processing Record 36 of Set 10 | airai
# Processing Record 37 of Set 10 | tekari
# Processing Record 38 of Set 10 | khuzhir
# Processing Record 39 of Set 10 | makung
# City not found. Skipping...
# Processing Record 40 of Set 10 | manacapuru
# Processing Record 41 of Set 10 | san patricio
# Processing Record 42 of Set 10 | sokoni
# Processing Record 43 of Set 10 | sayansk
# Processing Record 44 of Set 10 | weihe
# Processing Record 45 of Set 10 | bereznik
# Processing Record 46 of Set 10 | san cristobal
# Processing Record 47 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 48 of Set 10 | noumea
# Processing Record 49 of Set 10 | malartic
# Processing Record 0 of Set 11 | laguna de perlas
# Processing Record 1 of Set 11 | kruisfontein
# Processing Record 2 of Set 11 | lodwar
# Processing Record 3 of Set 11 | shaoguan
# Processing Record 4 of Set 11 | cuilco
# Processing Record 5 of Set 11 | nuuk
# Processing Record 6 of Set 11 | colac
# Processing Record 7 of Set 11 | kuminskiy
# Processing Record 8 of Set 11 | fukue
# Processing Record 9 of Set 11 | erdenet
# Processing Record 10 of Set 11 | yeniseysk
# Processing Record 11 of Set 11 | teahupoo
# Processing Record 12 of Set 11 | mariental
# Processing Record 13 of Set 11 | sioux lookout
# Processing Record 14 of Set 11 | arman
# Processing Record 15 of Set 11 | bantva
# Processing Record 16 of Set 11 | zheleznodorozhnyy
# Processing Record 17 of Set 11 | gat
# Processing Record 18 of Set 11 | idritsa
# Processing Record 19 of Set 11 | san vicente
# Processing Record 20 of Set 11 | likasi
# Processing Record 21 of Set 11 | osakarovka
# Processing Record 22 of Set 11 | smithers
# Processing Record 23 of Set 11 | gashua
# Processing Record 24 of Set 11 | srandakan
# Processing Record 25 of Set 11 | codrington
# Processing Record 26 of Set 11 | axixa do tocantins
# City not found. Skipping...
# Processing Record 27 of Set 11 | cohoes
# Processing Record 28 of Set 11 | phangnga
# Processing Record 29 of Set 11 | zaysan
# Processing Record 30 of Set 11 | mednogorsk
# Processing Record 31 of Set 11 | cabedelo
# Processing Record 32 of Set 11 | goba
# Processing Record 33 of Set 11 | virginia beach
# Processing Record 34 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 11 | bartica
# Processing Record 36 of Set 11 | kyra
# Processing Record 37 of Set 11 | sambava
# Processing Record 38 of Set 11 | francistown
# Processing Record 39 of Set 11 | amboasary
# Processing Record 40 of Set 11 | gobabis
# Processing Record 41 of Set 11 | mahanoro
# Processing Record 42 of Set 11 | chara
# Processing Record 43 of Set 11 | hami
# Processing Record 44 of Set 11 | ahipara
# Processing Record 45 of Set 11 | bose
# Processing Record 46 of Set 11 | discovery bay
# Processing Record 47 of Set 11 | kurara
# Processing Record 48 of Set 11 | great falls
# Processing Record 49 of Set 11 | natal
# Processing Record 0 of Set 12 | hamilton
# Processing Record 1 of Set 12 | hervey bay
# Processing Record 2 of Set 12 | anton lizardo
# Processing Record 3 of Set 12 | boende
# Processing Record 4 of Set 12 | mokhsogollokh
# Processing Record 5 of Set 12 | nouadhibou
# Processing Record 6 of Set 12 | vardo
# Processing Record 7 of Set 12 | san anselmo
# Processing Record 8 of Set 12 | harper
# Processing Record 9 of Set 12 | prince rupert
# Processing Record 10 of Set 12 | flinders
# Processing Record 11 of Set 12 | phan thiet
# Processing Record 12 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 13 of Set 12 | santa rosa
# Processing Record 14 of Set 12 | san juan
# Processing Record 15 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 16 of Set 12 | brylivka
# Processing Record 17 of Set 12 | mantua
# Processing Record 18 of Set 12 | te anau
# Processing Record 19 of Set 12 | bacsay
# Processing Record 20 of Set 12 | elmadag
# Processing Record 21 of Set 12 | fare
# Processing Record 22 of Set 12 | general roca
# Processing Record 23 of Set 12 | nurmijarvi
# Processing Record 24 of Set 12 | oktyabrskoye
# Processing Record 25 of Set 12 | abu samrah
# Processing Record 26 of Set 12 | kungurtug
# Processing Record 27 of Set 12 | haimen
# Processing Record 28 of Set 12 | quatre cocos
# Processing Record 29 of Set 12 | darayya
# Processing Record 30 of Set 12 | koupela
# Processing Record 31 of Set 12 | itahari
# City not found. Skipping...
# Processing Record 32 of Set 12 | karratha
# Processing Record 33 of Set 12 | pyu
# Processing Record 34 of Set 12 | ano mera
# Processing Record 35 of Set 12 | batagay
# Processing Record 36 of Set 12 | panzhihua
# Processing Record 37 of Set 12 | agirish
# Processing Record 38 of Set 12 | kamarion
# Processing Record 39 of Set 12 | inverell
# Processing Record 40 of Set 12 | kintampo
# Processing Record 41 of Set 12 | touros
# Processing Record 42 of Set 12 | kenai
# Processing Record 43 of Set 12 | chikwawa
# Processing Record 44 of Set 12 | koungou
# Processing Record 45 of Set 12 | port macquarie
# Processing Record 46 of Set 12 | alyangula
# Processing Record 47 of Set 12 | saint-georges
# Processing Record 48 of Set 12 | urupes
# Processing Record 49 of Set 12 | ravenna
# Processing Record 0 of Set 13 | kontagora
# Processing Record 1 of Set 13 | savinskiy
# Processing Record 2 of Set 13 | papara
# Processing Record 3 of Set 13 | port lincoln
# Processing Record 4 of Set 13 | verkhnevilyuysk
# Processing Record 5 of Set 13 | pleasanton
# Processing Record 6 of Set 13 | westport
# Processing Record 7 of Set 13 | shubarkuduk
# Processing Record 8 of Set 13 | hambantota
# Processing Record 9 of Set 13 | mogocha
# Processing Record 10 of Set 13 | nanakuli
# Processing Record 11 of Set 13 | zambezi
# Processing Record 12 of Set 13 | wyndham
# Processing Record 13 of Set 13 | horodnytsya
# Processing Record 14 of Set 13 | wagar
# Processing Record 15 of Set 13 | cockburn town
# Processing Record 16 of Set 13 | erenhot
# Processing Record 17 of Set 13 | hay river
# Processing Record 18 of Set 13 | trairi
# Processing Record 19 of Set 13 | nanortalik
# Processing Record 20 of Set 13 | chalus
# Processing Record 21 of Set 13 | sorong
# Processing Record 22 of Set 13 | maltahohe
# Processing Record 23 of Set 13 | yar-sale
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          570
# Lat           570
# Lng           570
# Max Temp      570
# Humidity      570
# Cloudiness    570
# Wind Speed    570
# Country       570
# Date          570
# dtype: int64

# %%
# Display sample data

city_data_df
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       qaanaaq  77.4840  -69.3632    -30.57        83          29
# 1       binzhou  37.3667  118.0167     -1.81        66         100
# 2       ushuaia -54.8000  -68.3000     10.81        62          40
# 3          oume  35.7839  139.2431      4.92        41          12
# 4      klaksvik  62.2266   -6.5890      5.51        77          73
# ..          ...      ...       ...       ...       ...         ...
# 565  nanortalik  60.1432  -45.2371     -2.00        79         100
# 566      chalus  36.6550   51.4204      4.70        93         100
# 567      sorong  -0.8833  131.2500     25.65        87         100
# 568   maltahohe -24.8333   16.9833     23.79        35          43
# 569    yar-sale  66.8333   70.8333    -35.85        98          20
#
#      Wind Speed Country        Date
# 0          2.84      GL  1673305084
# 1          2.72      CN  1673304930
# 2         10.80      AR  1673305085
# 3          5.06      JP  1673305086
# 4         11.92      FO  1673305087
# ..          ...     ...         ...
# 565        4.11      GL  1673305596
# 566        0.00      IR  1673305597
# 567        3.70      ID  1673305598
# 568        5.72      NA  1673305599
# 569        3.89      RU  1673305600
#
# [570 rows x 9 columns]

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data

city_data_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           qaanaaq  77.4840  -69.3632    -30.57        83          29
# 1           binzhou  37.3667  118.0167     -1.81        66         100
# 2           ushuaia -54.8000  -68.3000     10.81        62          40
# 3              oume  35.7839  139.2431      4.92        41          12
# 4          klaksvik  62.2266   -6.5890      5.51        77          73
# ...             ...      ...       ...       ...       ...         ...
# 565      nanortalik  60.1432  -45.2371     -2.00        79         100
# 566          chalus  36.6550   51.4204      4.70        93         100
# 567          sorong  -0.8833  131.2500     25.65        87         100
# 568       maltahohe -24.8333   16.9833     23.79        35          43
# 569        yar-sale  66.8333   70.8333    -35.85        98          20
#
#          Wind Speed Country        Date
# City_ID
# 0              2.84      GL  1673305084
# 1              2.72      CN  1673304930
# 2             10.80      AR  1673305085
# 3              5.06      JP  1673305086
# 4             11.92      FO  1673305087
# ...             ...     ...         ...
# 565            4.11      GL  1673305596
# 566            0.00      IR  1673305597
# 567            3.70      ID  1673305598
# 568            5.72     NaN  1673305599
# 569            3.89      RU  1673305600
#
# [570 rows x 9 columns]

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.title("City Max Temperature vs Latitude (2023-01-10)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid()
# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'],city_data_df['Humidity'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.title("City Humidity vs Latitude (2023-01-10)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.title("City Cloudiness vs Latitude (2023-01-10)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.title("Wind Speed vs Latitude (2023-01-10)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def computeLinReg (x,y):
    plt.scatter(x,y,marker='o', edgecolor='black')
    plt.grid()

    slope,intercept,rvalue,pvalue,std_err=linregress(x,y)
    regress_values=x*slope+intercept
    line_eq=print(f'The regression equation is y = {round(slope,2)}x + {round(intercept,2)}')
    r=print(f'The r-value is: {rvalue}')
    Rsq=print(f'R squared = {rvalue**2}')
    plt.plot(x,regress_values,"r-")
    
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df=city_data_df.loc[city_data_df['Lat']>=0]

# Display sample data
northern_hemi_df.head(12)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             qaanaaq  77.4840  -69.3632    -30.57        83          29
# 1             binzhou  37.3667  118.0167     -1.81        66         100
# 3                oume  35.7839  139.2431      4.92        41          12
# 4            klaksvik  62.2266   -6.5890      5.51        77          73
# 5             bedford  52.1346   -0.4663      5.07        81          79
# 6         thunder bay  48.4001  -89.3168     -5.01        74         100
# 7            mulhouse  47.6667    7.4167      6.62        84          75
# 9             talnakh  69.4865   88.3972    -42.11        90          37
# 11         butaritari   3.0707  172.7902     27.48        69         100
# 12          zhoucheng  35.9122  116.3117     -0.27        38          85
# 13              kapaa  22.0752 -159.3190     27.29        62           0
# 14       ponta do sol  32.6667  -17.1000     19.28        83          53
#
#          Wind Speed Country        Date
# City_ID
# 0              2.84      GL  1673305084
# 1              2.72      CN  1673304930
# 3              5.06      JP  1673305086
# 4             11.92      FO  1673305087
# 5              6.25      GB  1673305087
# 6              2.57      CA  1673305088
# 7              6.17      FR  1673305089
# 9              0.62      RU  1673304979
# 11             6.91      KI  1673305092
# 12             1.41      CN  1673305093
# 13             1.79      US  1673305094
# 14             1.49      PT  1673305095

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df.loc[city_data_df['Lat']<=0]

# Display sample data
southern_hemi_df.head(12)
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2               ushuaia -54.8000  -68.3000     10.81        62          40
# 8                 vaini -21.2000 -175.2000     31.09        79          75
# 10            cape town -33.9258   18.4232     19.23        88          20
# 15              mataura -46.1927  168.8643     23.54        45         100
# 16             cidreira -30.1811  -50.2056     22.55        78          94
# 19              le port -20.9373   55.2919     25.00        65           1
# 20               atuona  -9.8000 -139.0333     25.86        77          10
# 22             hermanus -34.4187   19.2345     20.45        91           5
# 24         punta arenas -53.1500  -70.9167     13.06        50          40
# 26       port elizabeth -33.9180   25.5701     23.51        92         100
# 33              rikitea -23.1203 -134.9692     25.88        76           5
# 36           walvis bay -22.9575   14.5053     19.49        82          47
#
#          Wind Speed Country        Date
# City_ID
# 2             10.80      AR  1673305085
# 8              5.66      TO  1673305090
# 10             2.06      ZA  1673305084
# 15             0.79      NZ  1673305095
# 16             7.61      BR  1673305096
# 19             2.57      RE  1673305099
# 20             6.95      PF  1673305099
# 22             1.57      ZA  1673305101
# 24            12.86      CL  1673305103
# 26             4.12      ZA  1673305104
# 33             7.68      PF  1673305111
# 36             1.03     NaN  1673305113

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
computeLinReg(northern_hemi_df['Lat'],northern_hemi_df['Max Temp'])
# Out:
# The regression equation is y = -0.82x + 34.28
# The r-value is: -0.855109662681456
# R squared = 0.7312125352111936

# %%
# Linear regression on Southern Hemisphere
computeLinReg(southern_hemi_df['Lat'],southern_hemi_df['Max Temp'])
# Out:
# The regression equation is y = 0.13x + 25.55
# The r-value is: 0.3790776473512481
# R squared = 0.1436998627213572

# %% [markdown]
# **Discussion about the linear relationship:** In the Northern hemisphere, there is a strong negative correlation between max temperature and degrees of latitude. In other words, the further away from the equator (0 degrees latitude) a city is located, the lower the max temperature is. The R-squared number is 0.73 - i.e. changes in latitude (x) explain 73% of the changes in variable y, max temperature.
#
# In the Southern hemisphere there is a weaker relationship between max temperature and latitude. However the figure shows that as latitude approaches 0, temperatures get warmer.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
computeLinReg(northern_hemi_df['Lat'],northern_hemi_df['Humidity'])
# Out:
# The regression equation is y = 0.38x + 60.88
# The r-value is: 0.39532883047062545
# R squared = 0.1562848842012725

# %%
# Southern Hemisphere
computeLinReg(southern_hemi_df['Lat'],southern_hemi_df['Humidity'])
# Out:
# The regression equation is y = 0.34x + 83.92
# The r-value is: 0.2606642897323001
# R squared = 0.06794587194164449

# %% [markdown]
# **Discussion about the linear relationship:** There appears to be a weak linear relationship between Latitude and humidity in both northern and southern hemispheres. This means that in the northern hemisphere, humidity increases slightly as you move away from the equator; and in the south humidity increases as you approach the equator. However, the low R-squared scores suggest there may be external factors (not Latitude) that explains this.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
computeLinReg(northern_hemi_df['Lat'],northern_hemi_df['Cloudiness'])
# Out:
# The regression equation is y = 0.42x + 43.13
# The r-value is: 0.21140098699345491
# R squared = 0.044690377301806895

# %%
# Southern Hemisphere
computeLinReg(southern_hemi_df['Lat'],southern_hemi_df['Cloudiness'])
# Out:
# The regression equation is y = 0.82x + 76.8
# The r-value is: 0.2837810855953821
# R squared = 0.08053170454169359

# %% [markdown]
# **Discussion about the linear relationship:** There appears to be a weak linear relationship between Latitude and cloudiness in both northern and southern hemispheres. This means that in the northern hemisphere, cloud cover increases slightly as you move away from the equator; and in the south cloud cover slightly increases as you approach the equator. However, the low R-squared scores suggest there may be external factors (not Latitude) that explains this.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
computeLinReg(northern_hemi_df['Lat'],northern_hemi_df['Wind Speed'])
# Out:
# The regression equation is y = 0.01x + 3.06
# The r-value is: 0.08832637168736394
# R squared = 0.007801547935454367

# %%
# Southern Hemisphere
computeLinReg(southern_hemi_df['Lat'],southern_hemi_df['Wind Speed'])
# Out:
# The regression equation is y = -0.06x + 2.21
# The r-value is: -0.3103484524760013
# R squared = 0.09631616195424883

# %% [markdown]
# **Discussion about the linear relationship:** There appears to be little to no linear relationship between Latitude and wind speed in either hemisphere.
